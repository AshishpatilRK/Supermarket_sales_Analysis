# %% [markdown]
# # Supermarket_Sales_Dataset

# %% [markdown]
# ![supermarket.jpg](attachment:supermarket.jpg)

# %% [markdown]
# ## Introduction

# %% [markdown]
# This is dataset of supermarket in cities of Myanmar(Burma). In this dataset , total sales of products and  gross income is calculated . Also customers gave their ratings for supermarket.

# %% [markdown]
# ## Variables used in the dataset

# %% [markdown]
# | |  Variables  | Type    | Subtype   |
# |---:|:-------------|:-----------|:------|
# | 1 | Invoice ID  | Categorical       | Nominal   |
# | 2 | Branch  | Categorical    | Nominal  |
# | 3 | City  | Categorical    | Nominal   |
# | 4 | Customer type  | Categorical    | Nominal   |
# | 5 | Gender  | Categorical    | Nominal   |
# | 7 | Unit Price  | Numeric    | Continuous   |
# | 8 | Quantity  | Numeric    | Discrete   |
# | 9 | Tax 5%  | Numeric    | Continuous   |
# | 10 | Total  | Numeric    | Continuous   |
# | 11 | Date  | Numeric    | Discrete   |
# | 12 | Time  | Numeric    | Continuous   |
# | 13 | Payments  | Categorical    | Nominal   |
# | 14 | cogs  | Numeric    | Continuous   |
# | 15 | gross margin percentage  | Numeric(constant)    |
# | 16 | gross income  | Numeric    | Continuous   |
# | 17| Rating  | Numeric    | Continuous   |

# %% [markdown]
#  Here,
#
#         Unit Price * Quantity + Tax % = Total
#
#         Total * Gross margin Percentage = gross income

# %% [markdown]
# ##  Importing libraries

# %%
import numpy as np  #  for numerical calculation
import pandas as pd        # for analysis 
import seaborn as sns         # for visualisation
import matplotlib.pyplot as plt  # for visualisation

# %% [markdown]
# ### Part 1

# %% [markdown]
# ### Basic exploratory steps

# %%
supermkt = pd.read_csv("supermarket_sales (1).csv") #  reading the dataset

# %%
supermkt.shape  # using shape function get number of observations(rows) and Variables(columns)
# Out:
# (1000, 17)

# %% [markdown]
# In this dataset 1000  observations(rows) and 17 Variables(columns)

# %%
supermkt.head()  # give 1 st 5 observations(rows)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
supermkt.tail() # give last st 5 observations(rows)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
supermkt.nunique()   # give nuber of unique values in variables
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %%
supermkt.drop_duplicates()  # remove duplicates
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
supermkt.describe(include = 'all')   # give summary of data
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %%
supermkt.info()  # show missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
supermkt.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# No missing cells in this dataset in any column.

# %% [markdown]
# ## Converting Datatypes

# %%
supermkt['Date'] =pd.to_datetime(supermkt['Date'])

# %%
supermkt['Time'] = pd.to_datetime(supermkt['Time'])

# %% [markdown]
# ## Add Columns

# %%
supermkt['Month'] = supermkt['Date'].dt.month
supermkt['day'] = supermkt['Date'].dt.day_name()

# %%
supermkt['Hour'] = supermkt['Time'].dt.hour

# %%
# rename of some variables 
supermkt = supermkt.rename(columns = {'Product line':'Product_line','Unit price': 'Unit_price','gross margin percentage': 'gross_margin_percentage','gross income':'gross_income','Customer type':'Customer_type'})

# %%
supermkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer_type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product_line             1000 non-null   object
#  6   Unit_price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# ### Part 2

# %% [markdown]
# ### 1. Is your supermarket more popular with males or females?

# %%
# use of count plot  for compare different branches 
fig, ax = plt.subplots(figsize=(12, 5))    
sns.countplot(x = 'Branch', hue = 'Gender',data = supermkt)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
supermkt.groupby(['Gender']).size() # use of group by function to calculate number of males and females
# Out:
# Gender
# Female    501
# Male      499
# dtype: int64

# %% [markdown]
# From above plot and with calculation supermarmaket is more popular with **females.**

# %% [markdown]
# ### 2. What does the customer rating look like and can you also comment on its skewness?

# %%
 # use of distributon plot to see distribution of customer rating
custmrating= sns.displot(supermkt, x="Rating",kde = True) 
plt.axvline(x=supermkt.Rating.mean(),color = 'red',alpha = 0.5, label = 'mean') # use of mean
plt.axvline(x=supermkt.Rating.median(),color = 'blue',alpha = 0.5, label = 'median') # use of median
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
supermkt["Rating"].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# above plot shows looks **normally distributed** i.e **Symmetric** with  very small near to zero skewness

# %% [markdown]
# ### 3. What can you say about the aggregate sales across the branches?

# %%
aggresales = supermkt.groupby('Branch')['Total'].sum() #  calculating  sales of branches use of groupby and sum()

# %%
aggresales
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
totalsales =  supermkt['Total'].sum()  # calculating total sales use of sum()
totalsales
# Out:
# 322966.749

# %%
# bar plot
sns.barplot(x=aggresales.index,y=aggresales.values,data=supermkt) .set_title("Sales across branchs")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# sales for branch A = 106200.3705 ,B =106197.6720, C  =  110568.7065
#
#  Totalsales  = 322966.749

# %% [markdown]
# Branch 'C' has the highest sales overall

# %% [markdown]
# ### 4. Which is the most popular payment method used by customers?

# %%
supermkt.groupby(['Payment']).size()  # calculating number of payment methpods of groupby and size()
# Out:
# Payment
# Cash           344
# Credit card    311
# Ewallet        345
# dtype: int64

# %%
payment_names = supermkt['Payment'].value_counts().index       # give index
payment_values = supermkt['Payment'].value_counts().values     # give values

# %%
# Pie plot
plt.pie(payment_values,labels=payment_names,autopct = '%1.2f%%',shadow=True,explode=[0.07,0,0])  # pie plot
plt.title("Most popular Payment method")  # title
plt.show()

# %% [markdown]
# **Ewallet** is largly use payment method by customers so it is most popular than others

# %% [markdown]
# ### Part3

# %% [markdown]
# ### 1. Does gross income affect customer ratings?

# %%
sns.scatterplot(x='Rating',y='gross_income', data =supermkt) # to see relation and distribution between numeric  and numeric variables
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='gross_income'>

# %%
supermkt['Rating'].corr(supermkt['gross_income'])
# Out:
# -0.03644170499701834

# %% [markdown]
# By the above plot and the correlation between Rating and Gross income is -0.03. So, the corr() value is nearly equal to 0 then there is no relationship between Rating and Gross income.<br>
# Thus, Gross income doesn't effect customer ratings.

# %% [markdown]
# ### 2. Which is the most profitable branch?

# %%
pftbrch = supermkt.groupby('Branch')['gross_income'].sum()   #use group by function to seperate branches and to calculate profit using gross income
pftbrch
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross_income, dtype: float64

# %%
sns.barplot(x=pftbrch.index,y=pftbrch.values,data=supermkt).set_title("Total Profit across branchs")  # bar plot
plt.ylabel('Total Gross_income')  # y label
plt.show()

# %%
pftbrch1= supermkt.groupby('Branch')['Total'].sum() #use group by function to seperate branches and to calculate profit using total

# %%
pftbrch1
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
sns.barplot(x=pftbrch1.index,y=pftbrch1.values,data=supermkt).set_title("Total Profit across branchs") # bar plot
plt.ylabel('Total income')   # y label
plt.show()

# %% [markdown]
# from above calcultions  **C** branch has large gross income i.e 5265.1765 and also large total sales 110568.7065.

# %% [markdown]
# ### 3. How is the relationship between Gender and Gross income?

# %%
sns.barplot(x="Gender",y="gross_income", data = supermkt)  # use of bar plots
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross_income'>

# %% [markdown]
# above plot shows that from **female** customers , supermarket get gross income more than male customers.

# %% [markdown]
# ### 4. Can you see any time trend in gross income?

# %%
sns.lineplot(x='Hour',y='gross_income',data=supermkt).set_title('Gross Income per Hour')  # line plot
plt.show() # show plot

# %% [markdown]
# Here, From above fig - **14th hour** is busiest

# %% [markdown]
# ### 5. Which product line helps you generate the most income?

# %%
pline = supermkt.groupby('Product_line')['gross_income'].sum()  #  seperate product lines according  to gross income
pline
# Out:
# Product_line
# Electronic accessories    2587.5015
# Fashion accessories       2585.9950
# Food and beverages        2673.5640
# Health and beauty         2342.5590
# Home and lifestyle        2564.8530
# Sports and travel         2624.8965
# Name: gross_income, dtype: float64

# %%
sns.barplot(x=pline.index,y=pline.values,data=supermkt).set_title("Product_line_income")  # bar plot
plt.ylabel('Total gross_income')   # y label
plt.xticks(rotation='vertical')  # vertical names
plt.show()

# %%
pline1 = supermkt.groupby('Product_line')['Total'].sum()  #seperate product lines according  to total
pline1
# Out:
# Product_line
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Food and beverages        56144.8440
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Sports and travel         55122.8265
# Name: Total, dtype: float64

# %%
sns.barplot(x=pline1.index,y=pline1.values,data=supermkt).set_title("Product_line_income")   # bar plot 
plt.ylabel('Total_income')  # y label
plt.xticks(rotation='vertical')  # rotation vertical
plt.show()

# %% [markdown]
# from these ,
#
#              gross income of Food and beverages is large i.e 2673.5640
#
#              total sales of Food and beverages is large i.e 56144.8440
#
#         so we can say that Food and beverages helps to generate most income

# %% [markdown]
# ### 6. What is the spending pattern of both males and females, meaning in which category do they spend more?

# %%
fig, ax = plt.subplots(figsize=(14, 5))        # fig size
sns.barplot(x = 'Product_line',y = 'Total', hue = 'Gender',data = supermkt)   # use of count plot to see pattern in  product line and Gender
# Out:
# <AxesSubplot:xlabel='Product_line', ylabel='Total'>

# %% [markdown]
# from above plot males spend more on Health and Beauty , Female spend more on Home and lifestyle.

# %% [markdown]
# ### 7. How many products are bought by customers?

# %%
supermkt['Quantity'].sum()   # use of sum() to calculate total products bought
# Out:
# 5510

# %%
df = supermkt.groupby('Customer_type')['Quantity'].sum()   # segregation of customers see their quantity
df
# Out:
# Customer_type
# Member    2785
# Normal    2725
# Name: Quantity, dtype: int64

# %% [markdown]
# * Total product brought by customers 5510
# * In that type member customers bought 2785 and Normal customers bought 2725 products

# %% [markdown]
# ### 8. Which day of the week has maximum sales?

# %%
sns.barplot(x="day",y="Total", data = supermkt)  # use of bar plots
# Out:
# <AxesSubplot:xlabel='day', ylabel='Total'>

# %% [markdown]
# **Saturday** has maximum sales

# %% [markdown]
# ### 9. Which hour of the day is busiest?

# %%
sns.barplot(x='Hour',y='Total',data=supermkt).set_title('Total Sales per Hour')  # Bar plot  hour vs total
plt.show()

# %% [markdown]
# **14 th hour** is busiest hour of the day.

# %% [markdown]
# ### 10. Which product line should your supermarket focus on?

# %%
df = supermkt.groupby('Product_line')['Total'].sum()   #getting minimum product line acco to total sales
df
# Out:
# Product_line
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Food and beverages        56144.8440
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Sports and travel         55122.8265
# Name: Total, dtype: float64

# %%
min(df)    # use min for to get  Health and beauty
# Out:
# 49193.739

# %%
sns.barplot(x=df.index,y=df.values,data=supermkt).set_title("Product_line_income")    # bar plot product line vs totol income
plt.ylabel('Total_income')  # y label
plt.xticks(rotation='vertical')  # x label
plt.show()

# %%
df1 = supermkt.groupby('Product_line')['gross_income'].sum()       # getting minimum product line acco to gross income
df1
# Out:
# Product_line
# Electronic accessories    2587.5015
# Fashion accessories       2585.9950
# Food and beverages        2673.5640
# Health and beauty         2342.5590
# Home and lifestyle        2564.8530
# Sports and travel         2624.8965
# Name: gross_income, dtype: float64

# %%
min(df)
# Out:
# 49193.739

# %%
sns.barplot(x=df1.index,y=df1.values,data=supermkt).set_title("Product_line_income")
plt.ylabel('Total_income')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# supermarket should focus on Health and beauty product line. because it has lowest sales and lowest gross income .i.e 49193.739 and 2342.55

# %% [markdown]
# ### 11. Which city should be chosen for expansion and what products should be focussed on?

# %%
df5 = supermkt.groupby('City')['Total'].sum()  # get max total sales of city
df5
# Out:
# City
# Mandalay     106197.6720
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Name: Total, dtype: float64

# %%
max(df5)   # use max
# Out:
# 110568.7065

# %%
sns.barplot(x=df5.index,y=df5.values).set_title("City_income")  # bar plot  city vs  total
# Out:
# Text(0.5, 1.0, 'City_income')

# %%
df6 = supermkt.groupby('City')['gross_income'].sum()  # get max gross income of city
df6
# Out:
# City
# Mandalay     5057.0320
# Naypyitaw    5265.1765
# Yangon       5057.1605
# Name: gross_income, dtype: float64

# %%
max(df6)   # use maximum
# Out:
# 5265.1765

# %%
sns.barplot(x=df6.index,y=df6.values).set_title("City_income")    # bar plot
# Out:
# Text(0.5, 1.0, 'City_income')

# %% [markdown]
# Naypyitaw has maximum gross income

# %%
fig, ax = plt.subplots(figsize=(14, 10))   # figure size
sns.countplot(x = 'Product_line', hue = 'City',data = supermkt)  # count plot for product line and City
# Out:
# <AxesSubplot:xlabel='Product_line', ylabel='count'>

# %% [markdown]
# From the above figures, ***Yangon and Mandalay*** are very close to sales and they are less when compared to Naypyitaw City.
# So, Supermarket owners should focus on both the cities for expansion and they can mostly focus to increase the sales of Health & Beauty, Food and Beverages to increase their income because now a days these are daily items which are used by the customers.
